# %% [markdown]
# # Stock Picking
# This Project explore the price history of SP 500 Stock by Varioius Method:
# + Fundmental Analysis
# + Time series analysis
# + Event Analysis
# + ....
# and make recommendation on future stock picking
#
# Authur: Wenxuan Zhang
#
# Date: Aug 15, 2017

# %% [markdown]
# ## Question 1 What Stock enjoyed the biggest increase in the past 5 years?

# %%
from pandas_datareader import data
import matplotlib.pyplot as plt
import pandas as pd

# %%
from pandas_datareader import data
import pandas as pd

SP500 = pd.read_csv("sp500.csv")
# Define the instruments to download. We would like to see Apple, Microsoft and the S&P500 index.
tickers = SP500["Symbol"]
tickers[len(tickers)] = "^GSPC"
# Define which online source one should use
data_source = 'google'

# We would like all available data from 01/01/2000 until 12/31/2016.
start_date = '2010-01-01'
end_date = '2016-12-31'

# User pandas_reader.data.DataReader to load the desired data. As simple as that.
panel_data = data.DataReader(tickers, data_source, start_date, end_date)

# Getting just the adjusted closing prices. This will return a Pandas DataFrame
# The index in this DataFrame is the major index of the panel_data.
close = panel_data.loc['Close']

# Getting all weekdays between 01/01/2000 and 12/31/2016
all_weekdays = pd.date_range(start=start_date, end=end_date,Freq='B')

# How do we align the existing prices in adj_close with our new set of dates?
# All we need to do is reindex close using all_weekdays as the new index
close = close.reindex(all_weekdays)

close.head(10)
# Out:
# /Users/wenxuanzhang/anaconda/lib/python2.7/site-packages/pandas_datareader/base.py:201: SymbolWarning: Failed to read symbol: '^GSPC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
#                 A  AAL    AAP   AAPL ABBV    ABC    ABT    ACN   ADBE  ADI  \
# 2010-01-01    NaN  NaN    NaN    NaN  NaN    NaN    NaN    NaN    NaN  NaN
# 2010-01-02    NaN  NaN    NaN    NaN  NaN    NaN    NaN    NaN    NaN  NaN
# 2010-01-03    NaN  NaN    NaN    NaN  NaN    NaN    NaN    NaN    NaN  NaN
# 2010-01-04   31.3  NaN  40.38  30.57  NaN  26.63  27.23  42.07  37.09  NaN
# 2010-01-05  30.96  NaN  40.14  30.63  NaN  26.44  27.01  42.33   37.7  NaN
# 2010-01-06  30.85  NaN  40.49  30.14  NaN  26.19  27.16  42.78  37.62  NaN
# 2010-01-07  30.81  NaN  40.48  30.08  NaN  25.77  27.38  42.74  36.89  NaN
# 2010-01-08   30.8  NaN  40.64  30.28  NaN  26.05  27.52  42.57  36.69  NaN
# 2010-01-09    NaN  NaN    NaN    NaN  NaN    NaN    NaN    NaN    NaN  NaN
# 2010-01-10    NaN  NaN    NaN    NaN  NaN    NaN    NaN    NaN    NaN  NaN
#
#             ...     XOM   XRAY    XRX  XYL   YHOO    YUM    ZBH   ZION  ZTS  \
# 2010-01-01  ...     NaN    NaN    NaN  NaN    NaN    NaN    NaN    NaN  NaN
# 2010-01-02  ...     NaN    NaN    NaN  NaN    NaN    NaN    NaN    NaN  NaN
# 2010-01-03  ...     NaN    NaN    NaN  NaN    NaN    NaN    NaN    NaN  NaN
# 2010-01-04  ...   69.15  35.33  34.52  NaN   17.1  35.09  60.02  13.33  NaN
# 2010-01-05  ...   69.42  34.91  34.56  NaN  17.23  34.97  61.92   13.8  NaN
# 2010-01-06  ...   70.02  35.14  34.24  NaN  17.17  34.72   61.9     15  NaN
# 2010-01-07  ...    69.8   35.6   34.4  NaN   16.7  34.71  63.32  16.68  NaN
# 2010-01-08  ...   69.52   35.6  34.28  NaN   16.7  34.72  61.99  16.41  NaN
# 2010-01-09  ...     NaN    NaN    NaN  NaN    NaN    NaN    NaN    NaN  NaN
# 2010-01-10  ...     NaN    NaN    NaN  NaN    NaN    NaN    NaN    NaN  NaN
#
#            ^GSPC
# 2010-01-01   NaN
# 2010-01-02   NaN
# 2010-01-03   NaN
# 2010-01-04   NaN
# 2010-01-05   NaN
# 2010-01-06   NaN
# 2010-01-07   NaN
# 2010-01-08   NaN
# 2010-01-09   NaN
# 2010-01-10   NaN
#
# [10 rows x 506 columns]

# %%
panel_data.to_excel("SP500.xlsx")

# %% [markdown]
# ## Which company has the highest growth over 5 years?
# Let take a look into the the Highest Period of the first Day of Analysis

# %%
High = pd.read_excel("SP500.xlsx",sheetname="High",index_col=0)

# %%
# define a typical function to calculate the 6 year growth rate
def f(x):
    return (x[len(x)-1]/x[0])
# define a lambda function 
lambda x : (x[len(x)-1]/x[0])
High.apply(f,axis=0)
growth= High.apply(lambda x : (x[len(x)-1]/x[0]),axis=0)
revenue = High.apply(lambda x: (x[len(x)-1]-x[0]),axis=0)
performance = pd.DataFrame({'growth': growth,'revenue':revenue,"Symbol":growth.index})
performance.merge(SP500,on = "Symbol",how = "left")

# %%
# Out:
#     Symbol     growth  revenue                                Name  \
# 0        A   1.448625    14.19            Agilent Technologies Inc
# 1      AAL        NaN      NaN             American Airlines Group
# 2      AAP   4.191033   130.96                  Advance Auto Parts
# 3     AAPL   3.825065    86.56                          Apple Inc.
# 4     ABBV        NaN      NaN                              AbbVie
# 5      ABC   2.978269    52.80              AmerisourceBergen Corp
# 6      ABT   1.424853    11.59                 Abbott Laboratories
# 7      ACN   2.795024    75.75                       Accenture plc
# 8     ADBE   2.794102    66.92                   Adobe Systems Inc
# 9      ADI        NaN      NaN                Analog Devices, Inc.
# 10     ADM   1.434987    13.85           Archer-Daniels-Midland Co
# 11     ADP   2.375746    59.90           Automatic Data Processing
# 12     ADS   3.491818   164.46               Alliance Data Systems
# 13    ADSK   2.919861    49.59                        Autodesk Inc
# 14     AEE   1.870534    24.61                         Ameren Corp
# 15     AEP   1.761667    27.42             American Electric Power
# 16     AES   0.860584    -1.91                            AES Corp
# 17     AET   3.770859    91.66                           Aetna Inc
# 18     AFL   1.470440    22.44                           AFLAC Inc
# 19     AGN        NaN      NaN                       Allergan, Plc
# 20     AIG   2.151932    35.18  American International Group, Inc.
# 21     AIV   2.787768    29.23         Apartment Investment & Mgmt
# 22     AIZ   3.091691    63.19                        Assurant Inc
# 23     AJG   2.286716    29.35           Arthur J. Gallagher & Co.
# 24    AKAM   2.592095    41.49             Akamai Technologies Inc
# 25     ALB   2.294456    49.50                      Albemarle Corp
# 26     ALK  10.106576    80.32                Alaska Air Group Inc
# 27     ALL   2.443789    44.05                       Allstate Corp
# 28    ALLE        NaN      NaN                            Allegion
# 29    ALXN   5.013317    99.45             Alexion Pharmaceuticals
# ..     ...        ...      ...                                 ...
# 476    WAT   2.161342    72.70                  Waters Corporation
# 477    WBA        NaN      NaN            Walgreens Boots Alliance
# 478    WDC   1.515284    23.60                     Western Digital
# 479    WEC   2.357257    34.04                Wec Energy Group Inc
# 480    WFC   2.014556    27.88                         Wells Fargo
# 481    WFM   2.232525    17.28                  Whole Foods Market
# 482    WHR   2.241153   102.06                     Whirlpool Corp.
# 483   WLTW   1.742490    52.65                Willis Towers Watson
# 484     WM   2.086982    37.24               Waste Management Inc.
# 485    WMB   1.461894    10.00                       Williams Cos.
# 486    WMT   1.269984    14.76                     Wal-Mart Stores
# 487    WRK        NaN      NaN                    WestRock Company
# 488     WU   1.138254     2.66                    Western Union Co
# 489     WY   0.685348   -13.98                  Weyerhaeuser Corp.
# 490    WYN   3.746835    56.42                   Wyndham Worldwide
# 491   WYNN   1.363211    23.30                    Wynn Resorts Ltd
# 492    XEC   2.493384    82.39                      Cimarex Energy
# 493    XEL   1.920954    19.69                     Xcel Energy Inc
# 494     XL        NaN      NaN                          XL Capital
# 495   XLNX   2.399688    35.86                          Xilinx Inc
# 496    XOM   1.309558    21.44                   Exxon Mobil Corp.
# 497   XRAY   1.637027    22.71                     Dentsply Sirona
# 498    XRX   1.004566     0.16                         Xerox Corp.
# 499    XYL        NaN      NaN                          Xylem Inc.
# 500   YHOO   2.267442    21.80                          Yahoo Inc.
# 501    YUM   1.812358    28.66                     Yum! Brands Inc
# 502    ZBH   1.728134    43.79              Zimmer Biomet Holdings
# 503   ZION   3.239342    29.94                       Zions Bancorp
# 504    ZTS        NaN      NaN                              Zoetis
# 505  ^GSPC        NaN      NaN                                 NaN
#
#                      Sector
# 0               Health Care
# 1               Industrials
# 2    Consumer Discretionary
# 3    Information Technology
# 4               Health Care
# 5               Health Care
# 6               Health Care
# 7    Information Technology
# 8    Information Technology
# 9    Information Technology
# 10         Consumer Staples
# 11   Information Technology
# 12   Information Technology
# 13   Information Technology
# 14                Utilities
# 15                Utilities
# 16                Utilities
# 17              Health Care
# 18               Financials
# 19              Health Care
# 20               Financials
# 21              Real Estate
# 22               Financials
# 23               Financials
# 24   Information Technology
# 25                Materials
# 26              Industrials
# 27               Financials
# 28              Industrials
# 29              Health Care
# ..                      ...
# 476             Health Care
# 477        Consumer Staples
# 478  Information Technology
# 479               Utilities
# 480              Financials
# 481        Consumer Staples
# 482  Consumer Discretionary
# 483              Financials
# 484             Industrials
# 485                  Energy
# 486        Consumer Staples
# 487               Materials
# 488  Information Technology
# 489             Real Estate
# 490  Consumer Discretionary
# 491  Consumer Discretionary
# 492                  Energy
# 493               Utilities
# 494              Financials
# 495  Information Technology
# 496                  Energy
# 497             Health Care
# 498  Information Technology
# 499             Industrials
# 500  Information Technology
# 501  Consumer Discretionary
# 502             Health Care
# 503              Financials
# 504             Health Care
# 505                     NaN
#
# [506 rows x 5 columns]
